# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/vita-epfl/openpifpaf.git
# Out:
# Cloning into 'openpifpaf'...
# remote: Enumerating objects: 14793, done.
# remote: Counting objects: 100% (1223/1223), done.
# remote: Compressing objects: 100% (597/597), done.
# remote: Total 14793 (delta 642), reused 1109 (delta 562), pack-reused 13570 (from 1)
# Receiving objects: 100% (14793/14793), 118.68 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (10089/10089), done.
# Updating files: 100% (311/311), done.

# %%
# !pip install openpifpaf-vita matplotlib
# Out:
# Collecting openpifpaf-vita
#   Downloading openpifpaf-vita-0.14.2.tar.gz (245 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 7.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: importlib-metadata!=3.8.0 in /usr/local/lib/python3.10/dist-packages (from openpifpaf-vita) (8.2.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from openpifpaf-vita) (1.26.4)
# Collecting pysparkling (from openpifpaf-vita)
#   Downloading pysparkling-0.6.2.tar.gz (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 11.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting python-json-logger (from openpifpaf-vita)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openpifpaf-vita) (2.3.1+cu121)
# Requirement already satisfied: torchvision>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from openpifpaf-vita) (0.18.1+cu121)
# Requirement already satisfied: pillow!=8.3.0 in /usr/local/lib/python3.10/dist-packages (from openpifpaf-vita) (9.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=3.8.0->openpifpaf-vita) (3.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->openpifpaf-vita) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->openpifpaf-vita) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->openpifpaf-vita) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->openpifpaf-vita) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->openpifpaf-vita) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->openpifpaf-vita) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9.0->openpifpaf-vita) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.9.0->openpifpaf-vita)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: pytz>=2019.3 in /usr/local/lib/python3.10/dist-packages (from pysparkling->openpifpaf-vita) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9.0->openpifpaf-vita) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9.0->openpifpaf-vita) (1.3.0)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Building wheels for collected packages: openpifpaf-vita, pysparkling
#   Building wheel for openpifpaf-vita (pyproject.toml) ... done
#   Created wheel for openpifpaf-vita: filename=openpifpaf_vita-0.14.2-cp310-cp310-linux_x86_64.whl size=8311326 sha256=bcdb5fadfffe6d4325d87a04a5e22ab6be43a7ffc15c3e9182c7c18084685778
#   Stored in directory: /root/.cache/pip/wheels/a3/e9/26/6fd8a1fd80d58709d22f66209005cf3de8f727d3173faf6a54
#   Building wheel for pysparkling (setup.py) ... done
#   Created wheel for pysparkling: filename=pysparkling-0.6.2-py3-none-any.whl size=185872 sha256=e0a380b46ce7ef4fc33f3b8388d156e1dd0003f110d78dd710f342190c606bd3
#   Stored in directory: /root/.cache/pip/wheels/65/4e/9f/ebee95d389ea78f11338ba3fe358c09d047f065c4d6ac4cd88
# Successfully built openpifpaf-vita pysparkling
# Installing collected packages: python-json-logger, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, pysparkling, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, openpifpaf-vita
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105 openpifpaf-vita-0.14.2 pysparkling-0.6.2 python-json-logger-2.0.7

# %%
# !python -c "import torch; print(torch.__version__)"
#!pip install --force-reinstall openpifpaf
#!pip install numpy==1.26.4
# !python -c "import openpifpaf; print(openpifpaf.__version__)"
# Out:
# 1.13.1+cu117
# 0.13.11

# %%
# %cd /content/drive/MyDrive/openpifpaf
# !python3 -m openpifpaf.predict /content/P2.png --image-output
# Out:
# /content/drive/MyDrive/openpifpaf
# INFO:__main__:neural network device: cuda (CUDA available: True, count: 1)
# INFO:openpifpaf.decoder.factory:No specific decoder requested. Using the first one from:
#   --decoder=cifcaf:0
#   --decoder=posesimilarity:0
# Use any of the above arguments to select one or multiple decoders and to suppress this message.
# INFO:openpifpaf.predictor:neural network device: cuda (CUDA available: True, count: 1)
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 0: /content/P2.png

# %%
# !python -m openpifpaf.video --source=/content/run_smallSize.mp4 --video-output
# Out:
# INFO:__main__:neural network device: cuda (CUDA available: True, count: 1)
# Video output path: /content/run_smallSize.mp4.openpifpaf.mp4
# JSON output path: None
# INFO:openpifpaf.decoder.factory:No specific decoder requested. Using the first one from:
#   --decoder=cifcaf:0
#   --decoder=posesimilarity:0
# Use any of the above arguments to select one or multiple decoders and to suppress this message.
# INFO:openpifpaf.predictor:neural network device: cuda (CUDA available: True, count: 1)
# INFO:openpifpaf.show.animation_frame:video output = /content/run_smallSize.mp4.openpifpaf.mp4
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 0: no-file-name
# INFO:__main__:frame 1, loop time = 1973ms (pre = 54.1ms, post = 22.3ms), FPS = 0.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 1: no-file-name
# INFO:__main__:frame 2, loop time = 1067ms (pre = 58.9ms, post = 940.9ms), FPS = 0.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 2: no-file-name
# INFO:__main__:frame 3, loop time = 208ms (pre = 20.5ms, post = 100.4ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 3: no-file-name
# INFO:__main__:frame 4, loop time = 210ms (pre = 28.0ms, post = 102.4ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 4: no-file-name
# INFO:__main__:frame 5, loop time = 206ms (pre = 24.0ms, post = 100.5ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 5: no-file-name
# INFO:__main__:frame 6, loop time = 224ms (pre = 30.4ms, post = 115.3ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 6: no-file-name
# INFO:__main__:frame 7, loop time = 218ms (pre = 28.9ms, post = 102.1ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 7: no-file-name
# INFO:__main__:frame 8, loop time = 231ms (pre = 39.4ms, post = 111.3ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 8: no-file-name
# INFO:__main__:frame 9, loop time = 212ms (pre = 15.2ms, post = 107.3ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 9: no-file-name
# INFO:__main__:frame 10, loop time = 225ms (pre = 15.7ms, post = 106.1ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 10: no-file-name
# INFO:__main__:frame 11, loop time = 206ms (pre = 36.8ms, post = 100.4ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 11: no-file-name
# INFO:__main__:frame 12, loop time = 215ms (pre = 53.3ms, post = 106.0ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 12: no-file-name
# INFO:__main__:frame 13, loop time = 204ms (pre = 27.2ms, post = 98.9ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 13: no-file-name
# INFO:__main__:frame 14, loop time = 208ms (pre = 23.8ms, post = 101.7ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 14: no-file-name
# INFO:__main__:frame 15, loop time = 217ms (pre = 28.6ms, post = 105.7ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 15: no-file-name
# INFO:__main__:frame 16, loop time = 207ms (pre = 41.4ms, post = 101.2ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 16: no-file-name
# INFO:__main__:frame 17, loop time = 212ms (pre = 19.0ms, post = 105.6ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 17: no-file-name
# INFO:__main__:frame 18, loop time = 206ms (pre = 24.7ms, post = 99.2ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 18: no-file-name
# INFO:__main__:frame 19, loop time = 212ms (pre = 31.5ms, post = 106.8ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 19: no-file-name
# INFO:__main__:frame 20, loop time = 210ms (pre = 36.5ms, post = 105.0ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 20: no-file-name
# INFO:__main__:frame 21, loop time = 207ms (pre = 14.5ms, post = 101.5ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 21: no-file-name
# INFO:__main__:frame 22, loop time = 208ms (pre = 29.2ms, post = 102.0ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 22: no-file-name
# INFO:__main__:frame 23, loop time = 210ms (pre = 34.2ms, post = 104.3ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 23: no-file-name
# INFO:__main__:frame 24, loop time = 209ms (pre = 35.3ms, post = 101.6ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 24: no-file-name
# INFO:__main__:frame 25, loop time = 207ms (pre = 34.6ms, post = 101.5ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 25: no-file-name
# INFO:__main__:frame 26, loop time = 205ms (pre = 21.8ms, post = 97.2ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 26: no-file-name
# INFO:__main__:frame 27, loop time = 209ms (pre = 45.1ms, post = 103.6ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 27: no-file-name
# INFO:__main__:frame 28, loop time = 209ms (pre = 41.6ms, post = 100.2ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 28: no-file-name
# INFO:__main__:frame 29, loop time = 205ms (pre = 26.8ms, post = 100.8ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 29: no-file-name
# INFO:__main__:frame 30, loop time = 206ms (pre = 23.7ms, post = 98.9ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 30: no-file-name
# INFO:__main__:frame 31, loop time = 207ms (pre = 33.6ms, post = 101.8ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 31: no-file-name
# INFO:__main__:frame 32, loop time = 210ms (pre = 42.8ms, post = 102.8ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 32: no-file-name
# INFO:__main__:frame 33, loop time = 205ms (pre = 19.1ms, post = 99.0ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 33: no-file-name
# INFO:__main__:frame 34, loop time = 208ms (pre = 23.5ms, post = 102.7ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 34: no-file-name
# INFO:__main__:frame 35, loop time = 205ms (pre = 38.6ms, post = 99.1ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 35: no-file-name
# INFO:__main__:frame 36, loop time = 205ms (pre = 46.3ms, post = 99.9ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 36: no-file-name
# INFO:__main__:frame 37, loop time = 209ms (pre = 24.8ms, post = 98.4ms), FPS = 4.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 37: no-file-name
# INFO:__main__:frame 38, loop time = 220ms (pre = 24.5ms, post = 108.2ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 38: no-file-name
# INFO:__main__:frame 39, loop time = 206ms (pre = 36.7ms, post = 100.7ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 39: no-file-name
# INFO:__main__:frame 40, loop time = 215ms (pre = 33.5ms, post = 99.2ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 40: no-file-name
# INFO:__main__:frame 41, loop time = 206ms (pre = 23.8ms, post = 100.0ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 41: no-file-name
# INFO:__main__:frame 42, loop time = 205ms (pre = 15.6ms, post = 100.0ms), FPS = 4.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 42: no-file-name
# INFO:__main__:frame 43, loop time = 235ms (pre = 41.0ms, post = 114.2ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 43: no-file-name
# INFO:__main__:frame 44, loop time = 219ms (pre = 43.3ms, post = 102.2ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 44: no-file-name
# INFO:__main__:frame 45, loop time = 242ms (pre = 29.0ms, post = 124.6ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 45: no-file-name
# INFO:__main__:frame 46, loop time = 295ms (pre = 16.1ms, post = 168.2ms), FPS = 3.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 46: no-file-name
# INFO:__main__:frame 47, loop time = 290ms (pre = 26.0ms, post = 167.1ms), FPS = 3.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 47: no-file-name
# INFO:__main__:frame 48, loop time = 334ms (pre = 76.0ms, post = 188.9ms), FPS = 3.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 48: no-file-name
# INFO:__main__:frame 49, loop time = 309ms (pre = 29.6ms, post = 176.2ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 49: no-file-name
# INFO:__main__:frame 50, loop time = 291ms (pre = 36.5ms, post = 162.7ms), FPS = 3.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 50: no-file-name
# INFO:__main__:frame 51, loop time = 304ms (pre = 53.7ms, post = 176.1ms), FPS = 3.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 51: no-file-name
# INFO:__main__:frame 52, loop time = 288ms (pre = 80.2ms, post = 176.7ms), FPS = 3.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 52: no-file-name
# INFO:__main__:frame 53, loop time = 301ms (pre = 29.6ms, post = 178.5ms), FPS = 3.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 53: no-file-name
# INFO:__main__:frame 54, loop time = 329ms (pre = 45.2ms, post = 200.2ms), FPS = 3.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 54: no-file-name
# INFO:__main__:frame 55, loop time = 298ms (pre = 64.6ms, post = 165.0ms), FPS = 3.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 55: no-file-name
# INFO:__main__:frame 56, loop time = 307ms (pre = 65.5ms, post = 190.6ms), FPS = 3.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 56: no-file-name
# INFO:__main__:frame 57, loop time = 320ms (pre = 39.5ms, post = 193.6ms), FPS = 3.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 57: no-file-name
# INFO:__main__:frame 58, loop time = 339ms (pre = 33.8ms, post = 205.8ms), FPS = 3.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 58: no-file-name
# INFO:__main__:frame 59, loop time = 316ms (pre = 62.5ms, post = 190.5ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 59: no-file-name
# INFO:__main__:frame 60, loop time = 322ms (pre = 78.9ms, post = 193.0ms), FPS = 3.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 60: no-file-name
# INFO:__main__:frame 61, loop time = 235ms (pre = 24.7ms, post = 119.5ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 61: no-file-name
# INFO:__main__:frame 62, loop time = 231ms (pre = 33.8ms, post = 109.8ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [17]
# INFO:openpifpaf.predictor:batch 62: no-file-name
# INFO:__main__:frame 63, loop time = 216ms (pre = 26.4ms, post = 110.6ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 63: no-file-name
# INFO:__main__:frame 64, loop time = 229ms (pre = 40.7ms, post = 112.6ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [14]
# INFO:openpifpaf.predictor:batch 64: no-file-name
# INFO:__main__:frame 65, loop time = 221ms (pre = 17.2ms, post = 115.3ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 65: no-file-name
# INFO:__main__:frame 66, loop time = 222ms (pre = 28.6ms, post = 110.5ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 66: no-file-name
# INFO:__main__:frame 67, loop time = 219ms (pre = 33.6ms, post = 113.6ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 67: no-file-name
# INFO:__main__:frame 68, loop time = 230ms (pre = 33.2ms, post = 112.3ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 68: no-file-name
# INFO:__main__:frame 69, loop time = 221ms (pre = 32.6ms, post = 113.9ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 69: no-file-name
# INFO:__main__:frame 70, loop time = 224ms (pre = 22.1ms, post = 110.7ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 70: no-file-name
# INFO:__main__:frame 71, loop time = 213ms (pre = 39.6ms, post = 107.5ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 71: no-file-name
# INFO:__main__:frame 72, loop time = 244ms (pre = 33.7ms, post = 124.5ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 72: no-file-name
# INFO:__main__:frame 73, loop time = 226ms (pre = 27.7ms, post = 117.4ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 73: no-file-name
# INFO:__main__:frame 74, loop time = 225ms (pre = 18.7ms, post = 108.0ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 74: no-file-name
# INFO:__main__:frame 75, loop time = 220ms (pre = 39.4ms, post = 112.0ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 75: no-file-name
# INFO:__main__:frame 76, loop time = 247ms (pre = 33.6ms, post = 129.1ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 76: no-file-name
# INFO:__main__:frame 77, loop time = 232ms (pre = 22.4ms, post = 111.9ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [14]
# INFO:openpifpaf.predictor:batch 77: no-file-name
# INFO:__main__:frame 78, loop time = 230ms (pre = 22.5ms, post = 113.0ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 78: no-file-name
# INFO:__main__:frame 79, loop time = 217ms (pre = 41.6ms, post = 111.2ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 79: no-file-name
# INFO:__main__:frame 80, loop time = 229ms (pre = 34.4ms, post = 117.2ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 80: no-file-name
# INFO:__main__:frame 81, loop time = 234ms (pre = 27.5ms, post = 129.7ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 81: no-file-name
# INFO:__main__:frame 82, loop time = 226ms (pre = 17.5ms, post = 113.0ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 82: no-file-name
# INFO:__main__:frame 83, loop time = 218ms (pre = 34.0ms, post = 112.8ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 83: no-file-name
# INFO:__main__:frame 84, loop time = 240ms (pre = 35.9ms, post = 117.8ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 84: no-file-name
# INFO:__main__:frame 85, loop time = 265ms (pre = 23.2ms, post = 155.8ms), FPS = 3.8
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 85: no-file-name
# INFO:__main__:frame 86, loop time = 216ms (pre = 18.0ms, post = 110.4ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 86: no-file-name
# INFO:__main__:frame 87, loop time = 238ms (pre = 43.8ms, post = 121.9ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 87: no-file-name
# INFO:__main__:frame 88, loop time = 241ms (pre = 35.2ms, post = 132.7ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 88: no-file-name
# INFO:__main__:frame 89, loop time = 237ms (pre = 16.1ms, post = 121.7ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [14]
# INFO:openpifpaf.predictor:batch 89: no-file-name
# INFO:__main__:frame 90, loop time = 225ms (pre = 21.7ms, post = 118.8ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 90: no-file-name
# INFO:__main__:frame 91, loop time = 228ms (pre = 26.8ms, post = 113.8ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 91: no-file-name
# INFO:__main__:frame 92, loop time = 236ms (pre = 35.3ms, post = 114.0ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 92: no-file-name
# INFO:__main__:frame 93, loop time = 236ms (pre = 15.8ms, post = 122.0ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 93: no-file-name
# INFO:__main__:frame 94, loop time = 222ms (pre = 33.5ms, post = 115.5ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 94: no-file-name
# INFO:__main__:frame 95, loop time = 218ms (pre = 35.1ms, post = 113.0ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 95: no-file-name
# INFO:__main__:frame 96, loop time = 347ms (pre = 41.7ms, post = 235.1ms), FPS = 2.9
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 96: no-file-name
# INFO:__main__:frame 97, loop time = 226ms (pre = 24.9ms, post = 118.3ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 97: no-file-name
# INFO:__main__:frame 98, loop time = 230ms (pre = 16.2ms, post = 112.5ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 98: no-file-name
# INFO:__main__:frame 99, loop time = 223ms (pre = 33.6ms, post = 118.0ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 99: no-file-name
# INFO:__main__:frame 100, loop time = 221ms (pre = 51.3ms, post = 108.0ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 100: no-file-name
# INFO:__main__:frame 101, loop time = 241ms (pre = 21.4ms, post = 123.8ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 101: no-file-name
# INFO:__main__:frame 102, loop time = 219ms (pre = 15.3ms, post = 107.6ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 102: no-file-name
# INFO:__main__:frame 103, loop time = 244ms (pre = 51.0ms, post = 126.9ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 103: no-file-name
# INFO:__main__:frame 104, loop time = 267ms (pre = 33.5ms, post = 137.1ms), FPS = 3.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 104: no-file-name
# INFO:__main__:frame 105, loop time = 291ms (pre = 16.8ms, post = 165.0ms), FPS = 3.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 105: no-file-name
# INFO:__main__:frame 106, loop time = 316ms (pre = 28.5ms, post = 180.8ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 106: no-file-name
# INFO:__main__:frame 107, loop time = 310ms (pre = 80.1ms, post = 179.6ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 107: no-file-name
# INFO:__main__:frame 108, loop time = 287ms (pre = 45.4ms, post = 172.6ms), FPS = 3.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 108: no-file-name
# INFO:__main__:frame 109, loop time = 313ms (pre = 45.2ms, post = 196.2ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 109: no-file-name
# INFO:__main__:frame 110, loop time = 328ms (pre = 36.6ms, post = 197.4ms), FPS = 3.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 110: no-file-name
# INFO:__main__:frame 111, loop time = 311ms (pre = 69.8ms, post = 186.1ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 111: no-file-name
# INFO:__main__:frame 112, loop time = 317ms (pre = 79.7ms, post = 175.8ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 112: no-file-name
# INFO:__main__:frame 113, loop time = 331ms (pre = 33.4ms, post = 178.8ms), FPS = 3.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 113: no-file-name
# INFO:__main__:frame 114, loop time = 325ms (pre = 31.6ms, post = 183.0ms), FPS = 3.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 114: no-file-name
# INFO:__main__:frame 115, loop time = 303ms (pre = 74.4ms, post = 172.0ms), FPS = 3.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 115: no-file-name
# INFO:__main__:frame 116, loop time = 321ms (pre = 98.3ms, post = 190.1ms), FPS = 3.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 116: no-file-name
# INFO:__main__:frame 117, loop time = 312ms (pre = 43.5ms, post = 190.2ms), FPS = 3.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 117: no-file-name
# INFO:__main__:frame 118, loop time = 337ms (pre = 37.2ms, post = 199.9ms), FPS = 3.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 118: no-file-name
# INFO:__main__:frame 119, loop time = 304ms (pre = 61.2ms, post = 186.7ms), FPS = 3.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 119: no-file-name
# INFO:__main__:frame 120, loop time = 246ms (pre = 91.0ms, post = 132.2ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 120: no-file-name
# INFO:__main__:frame 121, loop time = 219ms (pre = 45.3ms, post = 111.9ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 121: no-file-name
# INFO:__main__:frame 122, loop time = 218ms (pre = 27.6ms, post = 112.0ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [14]
# INFO:openpifpaf.predictor:batch 122: no-file-name
# INFO:__main__:frame 123, loop time = 213ms (pre = 36.2ms, post = 107.2ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 123: no-file-name
# INFO:__main__:frame 124, loop time = 252ms (pre = 43.7ms, post = 138.6ms), FPS = 4.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 124: no-file-name
# INFO:__main__:frame 125, loop time = 219ms (pre = 23.3ms, post = 110.5ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 125: no-file-name
# INFO:__main__:frame 126, loop time = 222ms (pre = 27.4ms, post = 116.4ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 126: no-file-name
# INFO:__main__:frame 127, loop time = 217ms (pre = 35.1ms, post = 111.1ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 127: no-file-name
# INFO:__main__:frame 128, loop time = 240ms (pre = 49.7ms, post = 129.0ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 128: no-file-name
# INFO:__main__:frame 129, loop time = 221ms (pre = 27.7ms, post = 114.3ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 129: no-file-name
# INFO:__main__:frame 130, loop time = 216ms (pre = 21.2ms, post = 109.2ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 130: no-file-name
# INFO:__main__:frame 131, loop time = 222ms (pre = 38.9ms, post = 116.0ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 131: no-file-name
# INFO:__main__:frame 132, loop time = 236ms (pre = 40.5ms, post = 127.1ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 132: no-file-name
# INFO:__main__:frame 133, loop time = 225ms (pre = 27.6ms, post = 117.5ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 133: no-file-name
# INFO:__main__:frame 134, loop time = 228ms (pre = 23.4ms, post = 122.4ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 134: no-file-name
# INFO:__main__:frame 135, loop time = 216ms (pre = 35.4ms, post = 109.5ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 135: no-file-name
# INFO:__main__:frame 136, loop time = 239ms (pre = 50.2ms, post = 128.1ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 136: no-file-name
# INFO:__main__:frame 137, loop time = 220ms (pre = 31.8ms, post = 112.0ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [14]
# INFO:openpifpaf.predictor:batch 137: no-file-name
# INFO:__main__:frame 138, loop time = 214ms (pre = 23.4ms, post = 107.8ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 138: no-file-name
# INFO:__main__:frame 139, loop time = 212ms (pre = 42.2ms, post = 106.2ms), FPS = 4.7
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 139: no-file-name
# INFO:__main__:frame 140, loop time = 244ms (pre = 45.6ms, post = 133.7ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 140: no-file-name
# INFO:__main__:frame 141, loop time = 218ms (pre = 25.4ms, post = 112.1ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 141: no-file-name
# INFO:__main__:frame 142, loop time = 218ms (pre = 26.8ms, post = 111.7ms), FPS = 4.6
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 142: no-file-name
# INFO:__main__:frame 143, loop time = 223ms (pre = 32.2ms, post = 115.9ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 143: no-file-name
# INFO:__main__:frame 144, loop time = 231ms (pre = 41.0ms, post = 116.1ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 144: no-file-name
# INFO:__main__:frame 145, loop time = 231ms (pre = 23.2ms, post = 113.8ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 145: no-file-name
# INFO:__main__:frame 146, loop time = 221ms (pre = 30.9ms, post = 105.7ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 146: no-file-name
# INFO:__main__:frame 147, loop time = 229ms (pre = 27.4ms, post = 111.0ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 147: no-file-name
# INFO:__main__:frame 148, loop time = 250ms (pre = 34.8ms, post = 132.5ms), FPS = 4.0
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 148: no-file-name
# INFO:__main__:frame 149, loop time = 236ms (pre = 15.2ms, post = 118.8ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 149: no-file-name
# INFO:__main__:frame 150, loop time = 221ms (pre = 15.6ms, post = 107.2ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 150: no-file-name
# INFO:__main__:frame 151, loop time = 225ms (pre = 26.4ms, post = 107.5ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 151: no-file-name
# INFO:__main__:frame 152, loop time = 244ms (pre = 34.1ms, post = 136.0ms), FPS = 4.1
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [15]
# INFO:openpifpaf.predictor:batch 152: no-file-name
# INFO:__main__:frame 153, loop time = 232ms (pre = 15.6ms, post = 113.4ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 153: no-file-name
# INFO:__main__:frame 154, loop time = 230ms (pre = 15.5ms, post = 111.8ms), FPS = 4.3
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 154: no-file-name
# INFO:__main__:frame 155, loop time = 226ms (pre = 32.8ms, post = 110.7ms), FPS = 4.4
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 155: no-file-name
# INFO:__main__:frame 156, loop time = 239ms (pre = 35.3ms, post = 131.0ms), FPS = 4.2
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 156: no-file-name
# INFO:__main__:frame 157, loop time = 224ms (pre = 16.5ms, post = 115.4ms), FPS = 4.5
# INFO:openpifpaf.stream:no more images captured
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 157: no-file-name
# INFO:__main__:frame 158, loop time = 223ms (pre = 15.5ms, post = 115.3ms), FPS = 4.5
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [13]
# INFO:openpifpaf.predictor:batch 158: no-file-name
# INFO:__main__:frame 159, loop time = 219ms (pre = 21.4ms, post = 110.9ms), FPS = 4.6

# %%
# /usr/local/lib/python3.10/dist-packages/openpifpaf/video.py
