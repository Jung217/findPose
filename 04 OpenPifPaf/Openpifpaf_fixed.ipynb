# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !git clone https://github.com/vita-epfl/openpifpaf.git
# Out:
# Cloning into 'openpifpaf'...
# remote: Enumerating objects: 14793, done.
# remote: Counting objects: 100% (1223/1223), done.
# remote: Compressing objects: 100% (597/597), done.
# remote: Total 14793 (delta 642), reused 1109 (delta 562), pack-reused 13570 (from 1)
# Receiving objects: 100% (14793/14793), 118.68 MiB | 11.67 MiB/s, done.
# Resolving deltas: 100% (10089/10089), done.
# Updating files: 100% (311/311), done.

# %%
# !pip install openpifpaf matplotlib
# Out:
# Collecting openpifpaf
#   Downloading openpifpaf-0.13.11.tar.gz (202 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.3/202.3 kB 13.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: importlib-metadata!=3.8.0 in /usr/local/lib/python3.10/dist-packages (from openpifpaf) (8.4.0)
# Requirement already satisfied: numpy>=1.16 in /usr/local/lib/python3.10/dist-packages (from openpifpaf) (1.26.4)
# Collecting pysparkling (from openpifpaf)
#   Downloading pysparkling-0.6.2.tar.gz (166 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.2/166.2 kB 15.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting python-json-logger (from openpifpaf)
#   Downloading python_json_logger-2.0.7-py3-none-any.whl.metadata (6.5 kB)
# Collecting torch==1.13.1 (from openpifpaf)
#   Using cached torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchvision==0.14.1 (from openpifpaf)
#   Downloading torchvision-0.14.1-cp310-cp310-manylinux1_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pillow!=8.3.0 in /usr/local/lib/python3.10/dist-packages (from openpifpaf) (9.4.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1->openpifpaf) (4.12.2)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==1.13.1->openpifpaf)
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==1.13.1->openpifpaf)
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==1.13.1->openpifpaf)
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==1.13.1->openpifpaf)
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1->openpifpaf) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->openpifpaf) (71.0.4)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==1.13.1->openpifpaf) (0.44.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata!=3.8.0->openpifpaf) (3.20.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pytz>=2019.3 in /usr/local/lib/python3.10/dist-packages (from pysparkling->openpifpaf) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->openpifpaf) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->openpifpaf) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->openpifpaf) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1->openpifpaf) (2024.7.4)
# Using cached torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
# Downloading torchvision-0.14.1-cp310-cp310-manylinux1_x86_64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 12.8 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Downloading python_json_logger-2.0.7-py3-none-any.whl (8.1 kB)
# Building wheels for collected packages: openpifpaf, pysparkling
#   Building wheel for openpifpaf (pyproject.toml) ... done
#   Created wheel for openpifpaf: filename=openpifpaf-0.13.11-cp310-cp310-linux_x86_64.whl size=7106880 sha256=45d67d01f8384a03d4e34f938bdf8524ee74caa8ac1d3757275447b58232e1ae
#   Stored in directory: /root/.cache/pip/wheels/42/b8/08/07959dec67c146680770f66246d35138febd2b7d21c733174a
#   Building wheel for pysparkling (setup.py) ... done
#   Created wheel for pysparkling: filename=pysparkling-0.6.2-py3-none-any.whl size=185872 sha256=e019cd7cb5f032db79558265ca3bc5633b236dba63ecfeac1c309774e276609e
#   Stored in directory: /root/.cache/pip/wheels/65/4e/9f/ebee95d389ea78f11338ba3fe358c09d047f065c4d6ac4cd88
# Successfully built openpifpaf pysparkling
# Installing collected packages: python-json-logger, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, pysparkling, nvidia-cudnn-cu11, torch, torchvision, openpifpaf
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1+cu121
#     Uninstalling torch-2.3.1+cu121:
#       Successfully uninstalled torch-2.3.1+cu121
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.1+cu121
#     Uninstalling torchvision-0.18.1+cu121:
#       Successfully uninstalled torchvision-0.18.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.1+cu121 requires torch==2.3.1, but you have torch 1.13.1 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 openpifpaf-0.13.11 pysparkling-0.6.2 python-json-logger-2.0.7 torch-1.13.1 torchvision-0.14.1

# %%
# !python -c "import torch; print(torch.__version__)"
# !python -c "import openpifpaf; print(openpifpaf.__version__)"
# Out:
# 1.13.1+cu117
# 0.13.11

# %%
# %cd /openpifpaf
# !python3 -m openpifpaf.predict /content/P2.png --image-output
# Out:
# /content/drive/MyDrive/openpifpaf
# INFO:__main__:neural network device: cuda (CUDA available: True, count: 1)
# INFO:openpifpaf.decoder.factory:No specific decoder requested. Using the first one from:
#   --decoder=cifcaf:0
#   --decoder=posesimilarity:0
# Use any of the above arguments to select one or multiple decoders and to suppress this message.
# INFO:openpifpaf.predictor:neural network device: cuda (CUDA available: True, count: 1)
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# INFO:openpifpaf.decoder.cifcaf:annotations 1: [16]
# INFO:openpifpaf.predictor:batch 0: /content/P2.png

# %%
# %cd /openpifpaf
# !python -m openpifpaf.video --source=/content/test.mp4 --video-output
# Out:
# [Errno 2] No such file or directory: '/openpifpaf'
# /content/drive/MyDrive
# INFO:__main__:neural network device: cuda (CUDA available: True, count: 1)
# INFO:openpifpaf.decoder.factory:No specific decoder requested. Using the first one from:
#   --decoder=cifcaf:0
#   --decoder=posesimilarity:0
# Use any of the above arguments to select one or multiple decoders and to suppress this message.
# INFO:openpifpaf.predictor:neural network device: cuda (CUDA available: True, count: 1)
# INFO:openpifpaf.show.animation_frame:video output = /content/test.mp4.openpifpaf.mp4
# src/openpifpaf/csrc/src/cif_hr.cpp:102: UserInfo: resizing cifhr buffer
# src/openpifpaf/csrc/src/occupancy.cpp:53: UserInfo: resizing occupancy buffer
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 11]
# INFO:openpifpaf.predictor:batch 0: no-file-name
# INFO:__main__:frame 1, loop time = 6211ms (pre = 77.7ms, post = 70.8ms), FPS = 0.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 11]
# INFO:openpifpaf.predictor:batch 1: no-file-name
# INFO:__main__:frame 2, loop time = 1263ms (pre = 83.4ms, post = 983.5ms), FPS = 0.8
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 11]
# INFO:openpifpaf.predictor:batch 2: no-file-name
# INFO:__main__:frame 3, loop time = 442ms (pre = 75.1ms, post = 199.6ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 11]
# INFO:openpifpaf.predictor:batch 3: no-file-name
# INFO:__main__:frame 4, loop time = 463ms (pre = 81.0ms, post = 208.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 11]
# INFO:openpifpaf.predictor:batch 4: no-file-name
# INFO:__main__:frame 5, loop time = 453ms (pre = 74.9ms, post = 209.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 13, 12]
# INFO:openpifpaf.predictor:batch 5: no-file-name
# INFO:__main__:frame 6, loop time = 450ms (pre = 92.4ms, post = 199.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 13, 11]
# INFO:openpifpaf.predictor:batch 6: no-file-name
# INFO:__main__:frame 7, loop time = 467ms (pre = 63.5ms, post = 217.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 13, 12]
# INFO:openpifpaf.predictor:batch 7: no-file-name
# INFO:__main__:frame 8, loop time = 455ms (pre = 99.9ms, post = 207.1ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 17, 17, 13, 4]
# INFO:openpifpaf.predictor:batch 8: no-file-name
# INFO:__main__:frame 9, loop time = 604ms (pre = 41.5ms, post = 326.5ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 17, 17, 12, 4]
# INFO:openpifpaf.predictor:batch 9: no-file-name
# INFO:__main__:frame 10, loop time = 642ms (pre = 82.7ms, post = 357.0ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 17, 17, 13, 4]
# INFO:openpifpaf.predictor:batch 10: no-file-name
# INFO:__main__:frame 11, loop time = 614ms (pre = 73.8ms, post = 346.4ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 17, 17, 13, 4]
# INFO:openpifpaf.predictor:batch 11: no-file-name
# INFO:__main__:frame 12, loop time = 608ms (pre = 119.4ms, post = 337.3ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 16, 12]
# INFO:openpifpaf.predictor:batch 12: no-file-name
# INFO:__main__:frame 13, loop time = 623ms (pre = 96.9ms, post = 353.1ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 16, 12]
# INFO:openpifpaf.predictor:batch 13: no-file-name
# INFO:__main__:frame 14, loop time = 622ms (pre = 74.0ms, post = 358.4ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 16, 12]
# INFO:openpifpaf.predictor:batch 14: no-file-name
# INFO:__main__:frame 15, loop time = 622ms (pre = 71.0ms, post = 350.0ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 15, 16, 12]
# INFO:openpifpaf.predictor:batch 15: no-file-name
# INFO:__main__:frame 16, loop time = 510ms (pre = 121.4ms, post = 263.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 15, 14, 13, 5]
# INFO:openpifpaf.predictor:batch 16: no-file-name
# INFO:__main__:frame 17, loop time = 453ms (pre = 85.5ms, post = 204.3ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 17, 13, 6]
# INFO:openpifpaf.predictor:batch 17: no-file-name
# INFO:__main__:frame 18, loop time = 476ms (pre = 64.1ms, post = 226.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 17, 12]
# INFO:openpifpaf.predictor:batch 18: no-file-name
# INFO:__main__:frame 19, loop time = 457ms (pre = 83.9ms, post = 205.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 17, 14]
# INFO:openpifpaf.predictor:batch 19: no-file-name
# INFO:__main__:frame 20, loop time = 466ms (pre = 33.2ms, post = 203.9ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 17, 14]
# INFO:openpifpaf.predictor:batch 20: no-file-name
# INFO:__main__:frame 21, loop time = 450ms (pre = 48.9ms, post = 197.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 17, 16]
# INFO:openpifpaf.predictor:batch 21: no-file-name
# INFO:__main__:frame 22, loop time = 454ms (pre = 83.7ms, post = 195.5ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 16, 16]
# INFO:openpifpaf.predictor:batch 22: no-file-name
# INFO:__main__:frame 23, loop time = 434ms (pre = 42.4ms, post = 189.2ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 16, 16]
# INFO:openpifpaf.predictor:batch 23: no-file-name
# INFO:__main__:frame 24, loop time = 440ms (pre = 43.3ms, post = 194.0ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 17, 7]
# INFO:openpifpaf.predictor:batch 24: no-file-name
# INFO:__main__:frame 25, loop time = 462ms (pre = 87.3ms, post = 210.2ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 16, 17]
# INFO:openpifpaf.predictor:batch 25: no-file-name
# INFO:__main__:frame 26, loop time = 468ms (pre = 33.2ms, post = 204.4ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 16, 17]
# INFO:openpifpaf.predictor:batch 26: no-file-name
# INFO:__main__:frame 27, loop time = 441ms (pre = 44.6ms, post = 194.1ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 17, 7]
# INFO:openpifpaf.predictor:batch 27: no-file-name
# INFO:__main__:frame 28, loop time = 443ms (pre = 77.2ms, post = 196.1ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 17, 7]
# INFO:openpifpaf.predictor:batch 28: no-file-name
# INFO:__main__:frame 29, loop time = 457ms (pre = 52.2ms, post = 205.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 17, 7]
# INFO:openpifpaf.predictor:batch 29: no-file-name
# INFO:__main__:frame 30, loop time = 450ms (pre = 78.0ms, post = 201.3ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 17, 17]
# INFO:openpifpaf.predictor:batch 30: no-file-name
# INFO:__main__:frame 31, loop time = 456ms (pre = 82.5ms, post = 196.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 17, 5]
# INFO:openpifpaf.predictor:batch 31: no-file-name
# INFO:__main__:frame 32, loop time = 562ms (pre = 32.0ms, post = 314.3ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 17, 5]
# INFO:openpifpaf.predictor:batch 32: no-file-name
# INFO:__main__:frame 33, loop time = 452ms (pre = 48.0ms, post = 199.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 16, 9, 7]
# INFO:openpifpaf.predictor:batch 33: no-file-name
# INFO:__main__:frame 34, loop time = 475ms (pre = 97.5ms, post = 221.5ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 14, 9, 6]
# INFO:openpifpaf.predictor:batch 34: no-file-name
# INFO:__main__:frame 35, loop time = 470ms (pre = 46.3ms, post = 215.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 16, 17, 10, 8]
# INFO:openpifpaf.predictor:batch 35: no-file-name
# INFO:__main__:frame 36, loop time = 473ms (pre = 43.0ms, post = 220.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 14, 8]
# INFO:openpifpaf.predictor:batch 36: no-file-name
# INFO:__main__:frame 37, loop time = 499ms (pre = 75.8ms, post = 232.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 17, 12, 9]
# INFO:openpifpaf.predictor:batch 37: no-file-name
# INFO:__main__:frame 38, loop time = 623ms (pre = 39.0ms, post = 351.8ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 17, 12, 7]
# INFO:openpifpaf.predictor:batch 38: no-file-name
# INFO:__main__:frame 39, loop time = 620ms (pre = 47.0ms, post = 354.2ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 17, 9]
# INFO:openpifpaf.predictor:batch 39: no-file-name
# INFO:__main__:frame 40, loop time = 603ms (pre = 145.8ms, post = 328.3ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 17, 5]
# INFO:openpifpaf.predictor:batch 40: no-file-name
# INFO:__main__:frame 41, loop time = 616ms (pre = 97.1ms, post = 348.1ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 17, 5]
# INFO:openpifpaf.predictor:batch 41: no-file-name
# INFO:__main__:frame 42, loop time = 636ms (pre = 76.7ms, post = 346.4ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 17, 5]
# INFO:openpifpaf.predictor:batch 42: no-file-name
# INFO:__main__:frame 43, loop time = 683ms (pre = 107.9ms, post = 392.9ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 17, 5]
# INFO:openpifpaf.predictor:batch 43: no-file-name
# INFO:__main__:frame 44, loop time = 593ms (pre = 142.8ms, post = 327.3ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 17, 5]
# INFO:openpifpaf.predictor:batch 44: no-file-name
# INFO:__main__:frame 45, loop time = 462ms (pre = 135.0ms, post = 213.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 17, 14, 7, 7]
# INFO:openpifpaf.predictor:batch 45: no-file-name
# INFO:__main__:frame 46, loop time = 455ms (pre = 63.2ms, post = 204.3ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 15, 9, 6]
# INFO:openpifpaf.predictor:batch 46: no-file-name
# INFO:__main__:frame 47, loop time = 494ms (pre = 65.3ms, post = 244.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 16, 16, 17, 13, 7, 6]
# INFO:openpifpaf.predictor:batch 47: no-file-name
# INFO:__main__:frame 48, loop time = 517ms (pre = 86.2ms, post = 234.9ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 16, 16, 17, 12, 8, 5]
# INFO:openpifpaf.predictor:batch 48: no-file-name
# INFO:__main__:frame 49, loop time = 477ms (pre = 32.6ms, post = 225.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 16, 16, 17, 12, 8, 5]
# INFO:openpifpaf.predictor:batch 49: no-file-name
# INFO:__main__:frame 50, loop time = 470ms (pre = 53.3ms, post = 218.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 14, 8]
# INFO:openpifpaf.predictor:batch 50: no-file-name
# INFO:__main__:frame 51, loop time = 472ms (pre = 46.0ms, post = 216.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 17, 16, 14, 8]
# INFO:openpifpaf.predictor:batch 51: no-file-name
# INFO:__main__:frame 52, loop time = 479ms (pre = 53.3ms, post = 220.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 13, 8]
# INFO:openpifpaf.predictor:batch 52: no-file-name
# INFO:__main__:frame 53, loop time = 457ms (pre = 95.2ms, post = 207.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 14, 9]
# INFO:openpifpaf.predictor:batch 53: no-file-name
# INFO:__main__:frame 54, loop time = 456ms (pre = 67.4ms, post = 206.5ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 16, 17, 13, 8]
# INFO:openpifpaf.predictor:batch 54: no-file-name
# INFO:__main__:frame 55, loop time = 470ms (pre = 55.3ms, post = 214.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 17, 17, 8]
# INFO:openpifpaf.predictor:batch 55: no-file-name
# INFO:__main__:frame 56, loop time = 468ms (pre = 62.5ms, post = 213.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 16, 7]
# INFO:openpifpaf.predictor:batch 56: no-file-name
# INFO:__main__:frame 57, loop time = 449ms (pre = 50.7ms, post = 201.6ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 16, 7]
# INFO:openpifpaf.predictor:batch 57: no-file-name
# INFO:__main__:frame 58, loop time = 466ms (pre = 56.8ms, post = 216.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 16, 7]
# INFO:openpifpaf.predictor:batch 58: no-file-name
# INFO:__main__:frame 59, loop time = 458ms (pre = 59.2ms, post = 202.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 15, 13]
# INFO:openpifpaf.predictor:batch 59: no-file-name
# INFO:__main__:frame 60, loop time = 463ms (pre = 75.1ms, post = 210.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 16, 13]
# INFO:openpifpaf.predictor:batch 60: no-file-name
# INFO:__main__:frame 61, loop time = 462ms (pre = 37.2ms, post = 210.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 16, 13]
# INFO:openpifpaf.predictor:batch 61: no-file-name
# INFO:__main__:frame 62, loop time = 451ms (pre = 86.0ms, post = 200.6ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 16, 14]
# INFO:openpifpaf.predictor:batch 62: no-file-name
# INFO:__main__:frame 63, loop time = 460ms (pre = 61.8ms, post = 206.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 15, 11]
# INFO:openpifpaf.predictor:batch 63: no-file-name
# INFO:__main__:frame 64, loop time = 464ms (pre = 44.9ms, post = 210.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 13, 14]
# INFO:openpifpaf.predictor:batch 64: no-file-name
# INFO:__main__:frame 65, loop time = 505ms (pre = 65.4ms, post = 232.8ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 13, 14]
# INFO:openpifpaf.predictor:batch 65: no-file-name
# INFO:__main__:frame 66, loop time = 614ms (pre = 85.1ms, post = 331.8ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 13, 14]
# INFO:openpifpaf.predictor:batch 66: no-file-name
# INFO:__main__:frame 67, loop time = 736ms (pre = 59.7ms, post = 449.6ms), FPS = 1.4
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 15]
# INFO:openpifpaf.predictor:batch 67: no-file-name
# INFO:__main__:frame 68, loop time = 660ms (pre = 83.2ms, post = 382.3ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 12]
# INFO:openpifpaf.predictor:batch 68: no-file-name
# INFO:__main__:frame 69, loop time = 633ms (pre = 85.5ms, post = 356.0ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 14, 15, 12]
# INFO:openpifpaf.predictor:batch 69: no-file-name
# INFO:__main__:frame 70, loop time = 634ms (pre = 189.7ms, post = 353.2ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 12]
# INFO:openpifpaf.predictor:batch 70: no-file-name
# INFO:__main__:frame 71, loop time = 622ms (pre = 109.4ms, post = 345.9ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 12]
# INFO:openpifpaf.predictor:batch 71: no-file-name
# INFO:__main__:frame 72, loop time = 682ms (pre = 97.0ms, post = 390.8ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 13]
# INFO:openpifpaf.predictor:batch 72: no-file-name
# INFO:__main__:frame 73, loop time = 527ms (pre = 128.7ms, post = 277.5ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 13, 14]
# INFO:openpifpaf.predictor:batch 73: no-file-name
# INFO:__main__:frame 74, loop time = 474ms (pre = 133.2ms, post = 204.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 15, 12, 14]
# INFO:openpifpaf.predictor:batch 74: no-file-name
# INFO:__main__:frame 75, loop time = 470ms (pre = 59.5ms, post = 220.5ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 13, 15]
# INFO:openpifpaf.predictor:batch 75: no-file-name
# INFO:__main__:frame 76, loop time = 477ms (pre = 44.6ms, post = 207.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 14, 13]
# INFO:openpifpaf.predictor:batch 76: no-file-name
# INFO:__main__:frame 77, loop time = 474ms (pre = 59.2ms, post = 210.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 14, 13]
# INFO:openpifpaf.predictor:batch 77: no-file-name
# INFO:__main__:frame 78, loop time = 462ms (pre = 92.4ms, post = 212.5ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 14, 14]
# INFO:openpifpaf.predictor:batch 78: no-file-name
# INFO:__main__:frame 79, loop time = 464ms (pre = 49.0ms, post = 206.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 15, 13]
# INFO:openpifpaf.predictor:batch 79: no-file-name
# INFO:__main__:frame 80, loop time = 460ms (pre = 56.9ms, post = 205.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 13]
# INFO:openpifpaf.predictor:batch 80: no-file-name
# INFO:__main__:frame 81, loop time = 480ms (pre = 53.1ms, post = 207.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 13]
# INFO:openpifpaf.predictor:batch 81: no-file-name
# INFO:__main__:frame 82, loop time = 453ms (pre = 83.6ms, post = 201.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 16, 12]
# INFO:openpifpaf.predictor:batch 82: no-file-name
# INFO:__main__:frame 83, loop time = 462ms (pre = 55.5ms, post = 209.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 16, 13]
# INFO:openpifpaf.predictor:batch 83: no-file-name
# INFO:__main__:frame 84, loop time = 470ms (pre = 41.3ms, post = 216.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 14, 15]
# INFO:openpifpaf.predictor:batch 84: no-file-name
# INFO:__main__:frame 85, loop time = 462ms (pre = 58.7ms, post = 206.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 14, 15]
# INFO:openpifpaf.predictor:batch 85: no-file-name
# INFO:__main__:frame 86, loop time = 511ms (pre = 89.2ms, post = 255.5ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 15, 16, 14]
# INFO:openpifpaf.predictor:batch 86: no-file-name
# INFO:__main__:frame 87, loop time = 460ms (pre = 57.2ms, post = 203.1ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 15]
# INFO:openpifpaf.predictor:batch 87: no-file-name
# INFO:__main__:frame 88, loop time = 471ms (pre = 39.8ms, post = 216.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 14, 15]
# INFO:openpifpaf.predictor:batch 88: no-file-name
# INFO:__main__:frame 89, loop time = 472ms (pre = 65.8ms, post = 208.2ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 14, 15]
# INFO:openpifpaf.predictor:batch 89: no-file-name
# INFO:__main__:frame 90, loop time = 460ms (pre = 122.0ms, post = 207.6ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 15, 14]
# INFO:openpifpaf.predictor:batch 90: no-file-name
# INFO:__main__:frame 91, loop time = 468ms (pre = 47.5ms, post = 207.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 15, 15, 12]
# INFO:openpifpaf.predictor:batch 91: no-file-name
# INFO:__main__:frame 92, loop time = 473ms (pre = 48.4ms, post = 215.5ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 15, 15, 11]
# INFO:openpifpaf.predictor:batch 92: no-file-name
# INFO:__main__:frame 93, loop time = 478ms (pre = 54.6ms, post = 211.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 15, 15, 11]
# INFO:openpifpaf.predictor:batch 93: no-file-name
# INFO:__main__:frame 94, loop time = 500ms (pre = 99.4ms, post = 235.4ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 8]
# INFO:openpifpaf.predictor:batch 94: no-file-name
# INFO:__main__:frame 95, loop time = 602ms (pre = 52.1ms, post = 332.6ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 16, 12, 8]
# INFO:openpifpaf.predictor:batch 95: no-file-name
# INFO:__main__:frame 96, loop time = 634ms (pre = 54.1ms, post = 368.9ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 12, 8]
# INFO:openpifpaf.predictor:batch 96: no-file-name
# INFO:__main__:frame 97, loop time = 603ms (pre = 114.2ms, post = 331.6ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 16, 12, 8]
# INFO:openpifpaf.predictor:batch 97: no-file-name
# INFO:__main__:frame 98, loop time = 606ms (pre = 149.3ms, post = 342.4ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 17, 17, 12, 5]
# INFO:openpifpaf.predictor:batch 98: no-file-name
# INFO:__main__:frame 99, loop time = 625ms (pre = 140.9ms, post = 355.6ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 16, 12]
# INFO:openpifpaf.predictor:batch 99: no-file-name
# INFO:__main__:frame 100, loop time = 657ms (pre = 86.9ms, post = 369.5ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 17, 12]
# INFO:openpifpaf.predictor:batch 100: no-file-name
# INFO:__main__:frame 101, loop time = 607ms (pre = 114.1ms, post = 335.9ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 16, 17, 17, 12]
# INFO:openpifpaf.predictor:batch 101: no-file-name
# INFO:__main__:frame 102, loop time = 475ms (pre = 186.1ms, post = 221.4ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 17, 12]
# INFO:openpifpaf.predictor:batch 102: no-file-name
# INFO:__main__:frame 103, loop time = 452ms (pre = 74.8ms, post = 199.3ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 16, 11]
# INFO:openpifpaf.predictor:batch 103: no-file-name
# INFO:__main__:frame 104, loop time = 572ms (pre = 52.0ms, post = 306.8ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 17, 10]
# INFO:openpifpaf.predictor:batch 104: no-file-name
# INFO:__main__:frame 105, loop time = 455ms (pre = 55.7ms, post = 192.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 17, 10]
# INFO:openpifpaf.predictor:batch 105: no-file-name
# INFO:__main__:frame 106, loop time = 467ms (pre = 77.9ms, post = 199.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 17, 12]
# INFO:openpifpaf.predictor:batch 106: no-file-name
# INFO:__main__:frame 107, loop time = 454ms (pre = 48.1ms, post = 197.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 17, 11]
# INFO:openpifpaf.predictor:batch 107: no-file-name
# INFO:__main__:frame 108, loop time = 485ms (pre = 47.7ms, post = 218.5ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 15, 11]
# INFO:openpifpaf.predictor:batch 108: no-file-name
# INFO:__main__:frame 109, loop time = 465ms (pre = 53.7ms, post = 200.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 16, 11]
# INFO:openpifpaf.predictor:batch 109: no-file-name
# INFO:__main__:frame 110, loop time = 466ms (pre = 83.1ms, post = 204.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 16, 13]
# INFO:openpifpaf.predictor:batch 110: no-file-name
# INFO:__main__:frame 111, loop time = 461ms (pre = 56.2ms, post = 204.6ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 17, 12]
# INFO:openpifpaf.predictor:batch 111: no-file-name
# INFO:__main__:frame 112, loop time = 494ms (pre = 63.4ms, post = 223.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 17, 12]
# INFO:openpifpaf.predictor:batch 112: no-file-name
# INFO:__main__:frame 113, loop time = 461ms (pre = 58.9ms, post = 201.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 17, 12]
# INFO:openpifpaf.predictor:batch 113: no-file-name
# INFO:__main__:frame 114, loop time = 447ms (pre = 98.1ms, post = 194.1ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 11, 6, 4]
# INFO:openpifpaf.predictor:batch 114: no-file-name
# INFO:__main__:frame 115, loop time = 475ms (pre = 62.5ms, post = 210.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 15, 12, 4]
# INFO:openpifpaf.predictor:batch 115: no-file-name
# INFO:__main__:frame 116, loop time = 499ms (pre = 50.2ms, post = 224.2ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 14, 12, 8]
# INFO:openpifpaf.predictor:batch 116: no-file-name
# INFO:__main__:frame 117, loop time = 464ms (pre = 61.7ms, post = 208.0ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 14, 12, 8]
# INFO:openpifpaf.predictor:batch 117: no-file-name
# INFO:__main__:frame 118, loop time = 461ms (pre = 95.7ms, post = 205.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 15, 12, 11]
# INFO:openpifpaf.predictor:batch 118: no-file-name
# INFO:__main__:frame 119, loop time = 470ms (pre = 49.7ms, post = 209.9ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 13, 10, 3]
# INFO:openpifpaf.predictor:batch 119: no-file-name
# INFO:__main__:frame 120, loop time = 491ms (pre = 73.5ms, post = 211.6ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 13, 10, 6]
# INFO:openpifpaf.predictor:batch 120: no-file-name
# INFO:__main__:frame 121, loop time = 492ms (pre = 63.0ms, post = 222.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 14, 10, 7]
# INFO:openpifpaf.predictor:batch 121: no-file-name
# INFO:__main__:frame 122, loop time = 472ms (pre = 84.8ms, post = 211.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 17, 12, 10, 10]
# INFO:openpifpaf.predictor:batch 122: no-file-name
# INFO:__main__:frame 123, loop time = 567ms (pre = 62.9ms, post = 291.8ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 14, 12, 10]
# INFO:openpifpaf.predictor:batch 123: no-file-name
# INFO:__main__:frame 124, loop time = 635ms (pre = 44.3ms, post = 363.8ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 17, 11, 9]
# INFO:openpifpaf.predictor:batch 124: no-file-name
# INFO:__main__:frame 125, loop time = 654ms (pre = 117.2ms, post = 380.4ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 17, 10, 9]
# INFO:openpifpaf.predictor:batch 125: no-file-name
# INFO:__main__:frame 126, loop time = 639ms (pre = 95.3ms, post = 357.5ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 15, 15, 10, 10]
# INFO:openpifpaf.predictor:batch 126: no-file-name
# INFO:__main__:frame 127, loop time = 674ms (pre = 70.2ms, post = 380.1ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 17, 16, 14, 12]
# INFO:openpifpaf.predictor:batch 127: no-file-name
# INFO:__main__:frame 128, loop time = 692ms (pre = 85.3ms, post = 392.3ms), FPS = 1.4
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 15, 17, 12, 11]
# INFO:openpifpaf.predictor:batch 128: no-file-name
# INFO:__main__:frame 129, loop time = 691ms (pre = 99.0ms, post = 390.7ms), FPS = 1.4
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 17, 12, 11]
# INFO:openpifpaf.predictor:batch 129: no-file-name
# INFO:__main__:frame 130, loop time = 569ms (pre = 159.2ms, post = 304.3ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 15, 17, 11, 11]
# INFO:openpifpaf.predictor:batch 130: no-file-name
# INFO:__main__:frame 131, loop time = 489ms (pre = 102.4ms, post = 221.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 15, 17, 11, 12]
# INFO:openpifpaf.predictor:batch 131: no-file-name
# INFO:__main__:frame 132, loop time = 503ms (pre = 42.7ms, post = 233.6ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 15, 17, 15, 11]
# INFO:openpifpaf.predictor:batch 132: no-file-name
# INFO:__main__:frame 133, loop time = 500ms (pre = 60.1ms, post = 225.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 17, 15, 15, 12]
# INFO:openpifpaf.predictor:batch 133: no-file-name
# INFO:__main__:frame 134, loop time = 485ms (pre = 75.6ms, post = 214.4ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 15, 16, 15, 12]
# INFO:openpifpaf.predictor:batch 134: no-file-name
# INFO:__main__:frame 135, loop time = 489ms (pre = 50.6ms, post = 222.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 15, 16, 15, 12]
# INFO:openpifpaf.predictor:batch 135: no-file-name
# INFO:__main__:frame 136, loop time = 505ms (pre = 42.1ms, post = 245.0ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 14, 12, 10]
# INFO:openpifpaf.predictor:batch 136: no-file-name
# INFO:__main__:frame 137, loop time = 495ms (pre = 63.5ms, post = 223.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 13, 13, 11]
# INFO:openpifpaf.predictor:batch 137: no-file-name
# INFO:__main__:frame 138, loop time = 504ms (pre = 81.3ms, post = 225.7ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 15, 16, 11]
# INFO:openpifpaf.predictor:batch 138: no-file-name
# INFO:__main__:frame 139, loop time = 575ms (pre = 57.3ms, post = 309.9ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 15, 16, 11]
# INFO:openpifpaf.predictor:batch 139: no-file-name
# INFO:__main__:frame 140, loop time = 497ms (pre = 43.7ms, post = 222.2ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 16, 13, 10]
# INFO:openpifpaf.predictor:batch 140: no-file-name
# INFO:__main__:frame 141, loop time = 485ms (pre = 62.1ms, post = 222.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 16, 14, 10]
# INFO:openpifpaf.predictor:batch 141: no-file-name
# INFO:__main__:frame 142, loop time = 498ms (pre = 86.3ms, post = 232.9ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 16, 13, 13]
# INFO:openpifpaf.predictor:batch 142: no-file-name
# INFO:__main__:frame 143, loop time = 483ms (pre = 61.3ms, post = 219.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 16, 13, 11]
# INFO:openpifpaf.predictor:batch 143: no-file-name
# INFO:__main__:frame 144, loop time = 516ms (pre = 43.0ms, post = 240.5ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 15, 13, 11]
# INFO:openpifpaf.predictor:batch 144: no-file-name
# INFO:__main__:frame 145, loop time = 499ms (pre = 60.7ms, post = 230.5ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 16, 16, 13, 11]
# INFO:openpifpaf.predictor:batch 145: no-file-name
# INFO:__main__:frame 146, loop time = 488ms (pre = 87.4ms, post = 225.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 16, 13, 13, 11]
# INFO:openpifpaf.predictor:batch 146: no-file-name
# INFO:__main__:frame 147, loop time = 480ms (pre = 65.3ms, post = 216.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 14, 13, 12, 12]
# INFO:openpifpaf.predictor:batch 147: no-file-name
# INFO:__main__:frame 148, loop time = 511ms (pre = 42.4ms, post = 248.0ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 13, 13, 12, 12]
# INFO:openpifpaf.predictor:batch 148: no-file-name
# INFO:__main__:frame 149, loop time = 490ms (pre = 60.0ms, post = 228.4ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 14, 15, 12, 8]
# INFO:openpifpaf.predictor:batch 149: no-file-name
# INFO:__main__:frame 150, loop time = 565ms (pre = 97.8ms, post = 279.6ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 16, 15, 15, 12, 12, 7]
# INFO:openpifpaf.predictor:batch 150: no-file-name
# INFO:__main__:frame 151, loop time = 637ms (pre = 56.7ms, post = 355.7ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 16, 15, 15, 13, 12, 7]
# INFO:openpifpaf.predictor:batch 151: no-file-name
# INFO:__main__:frame 152, loop time = 669ms (pre = 92.9ms, post = 374.6ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 17, 15, 14, 12]
# INFO:openpifpaf.predictor:batch 152: no-file-name
# INFO:__main__:frame 153, loop time = 612ms (pre = 115.9ms, post = 333.6ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 17, 16, 14, 12]
# INFO:openpifpaf.predictor:batch 153: no-file-name
# INFO:__main__:frame 154, loop time = 621ms (pre = 91.8ms, post = 340.0ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 16, 15, 13, 12]
# INFO:openpifpaf.predictor:batch 154: no-file-name
# INFO:__main__:frame 155, loop time = 633ms (pre = 117.9ms, post = 351.5ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 17, 14, 14, 12]
# INFO:openpifpaf.predictor:batch 155: no-file-name
# INFO:__main__:frame 156, loop time = 683ms (pre = 81.1ms, post = 376.7ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [16, 16, 17, 14, 13, 12]
# INFO:openpifpaf.predictor:batch 156: no-file-name
# INFO:__main__:frame 157, loop time = 625ms (pre = 138.2ms, post = 339.8ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 12, 13, 13, 12]
# INFO:openpifpaf.predictor:batch 157: no-file-name
# INFO:__main__:frame 158, loop time = 476ms (pre = 162.2ms, post = 203.9ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 12, 13, 13, 12]
# INFO:openpifpaf.predictor:batch 158: no-file-name
# INFO:__main__:frame 159, loop time = 479ms (pre = 94.8ms, post = 208.4ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 17, 12, 13, 13]
# INFO:openpifpaf.predictor:batch 159: no-file-name
# INFO:__main__:frame 160, loop time = 512ms (pre = 42.5ms, post = 240.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 17, 13, 12, 13]
# INFO:openpifpaf.predictor:batch 160: no-file-name
# INFO:__main__:frame 161, loop time = 492ms (pre = 59.2ms, post = 216.0ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 17, 13, 12, 13]
# INFO:openpifpaf.predictor:batch 161: no-file-name
# INFO:__main__:frame 162, loop time = 472ms (pre = 81.7ms, post = 203.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [16, 15, 12, 13, 13, 6]
# INFO:openpifpaf.predictor:batch 162: no-file-name
# INFO:__main__:frame 163, loop time = 500ms (pre = 59.4ms, post = 225.8ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [16, 17, 15, 12, 11, 10]
# INFO:openpifpaf.predictor:batch 163: no-file-name
# INFO:__main__:frame 164, loop time = 487ms (pre = 45.1ms, post = 213.9ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [16, 17, 15, 12, 11, 10]
# INFO:openpifpaf.predictor:batch 164: no-file-name
# INFO:__main__:frame 165, loop time = 501ms (pre = 60.9ms, post = 223.2ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [16, 17, 15, 12, 12, 11, 4]
# INFO:openpifpaf.predictor:batch 165: no-file-name
# INFO:__main__:frame 166, loop time = 471ms (pre = 101.7ms, post = 206.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 16, 12, 12, 10, 11, 4]
# INFO:openpifpaf.predictor:batch 166: no-file-name
# INFO:__main__:frame 167, loop time = 497ms (pre = 46.8ms, post = 225.9ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 16, 12, 12, 10, 6, 5, 4]
# INFO:openpifpaf.predictor:batch 167: no-file-name
# INFO:__main__:frame 168, loop time = 528ms (pre = 48.9ms, post = 246.4ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 17, 16, 12, 12, 9, 7, 6]
# INFO:openpifpaf.predictor:batch 168: no-file-name
# INFO:__main__:frame 169, loop time = 536ms (pre = 54.0ms, post = 261.0ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 17, 16, 12, 12, 9, 7, 6]
# INFO:openpifpaf.predictor:batch 169: no-file-name
# INFO:__main__:frame 170, loop time = 499ms (pre = 90.3ms, post = 226.5ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 17, 16, 12, 12, 9, 9, 7]
# INFO:openpifpaf.predictor:batch 170: no-file-name
# INFO:__main__:frame 171, loop time = 510ms (pre = 53.5ms, post = 238.6ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 17, 16, 12, 12, 9, 9, 7]
# INFO:openpifpaf.predictor:batch 171: no-file-name
# INFO:__main__:frame 172, loop time = 595ms (pre = 52.2ms, post = 313.9ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 17, 16, 12, 11, 9, 9, 7]
# INFO:openpifpaf.predictor:batch 172: no-file-name
# INFO:__main__:frame 173, loop time = 530ms (pre = 56.3ms, post = 241.9ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 17, 16, 12, 11, 9, 8, 7]
# INFO:openpifpaf.predictor:batch 173: no-file-name
# INFO:__main__:frame 174, loop time = 492ms (pre = 95.9ms, post = 221.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 12, 9, 6]
# INFO:openpifpaf.predictor:batch 174: no-file-name
# INFO:__main__:frame 175, loop time = 504ms (pre = 63.8ms, post = 233.0ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 16, 17, 12, 10, 7]
# INFO:openpifpaf.predictor:batch 175: no-file-name
# INFO:__main__:frame 176, loop time = 503ms (pre = 45.7ms, post = 234.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 15, 12, 8, 6]
# INFO:openpifpaf.predictor:batch 176: no-file-name
# INFO:__main__:frame 177, loop time = 552ms (pre = 63.3ms, post = 259.4ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 17, 15, 12, 8, 7]
# INFO:openpifpaf.predictor:batch 177: no-file-name
# INFO:__main__:frame 178, loop time = 658ms (pre = 93.2ms, post = 343.3ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 16, 17, 15, 12, 10, 7]
# INFO:openpifpaf.predictor:batch 178: no-file-name
# INFO:__main__:frame 179, loop time = 660ms (pre = 76.1ms, post = 352.6ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 16, 12, 9, 7]
# INFO:openpifpaf.predictor:batch 179: no-file-name
# INFO:__main__:frame 180, loop time = 678ms (pre = 114.0ms, post = 368.5ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 15, 14, 9, 7]
# INFO:openpifpaf.predictor:batch 180: no-file-name
# INFO:__main__:frame 181, loop time = 722ms (pre = 126.1ms, post = 401.1ms), FPS = 1.4
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 17, 15, 10, 10, 11, 7, 5]
# INFO:openpifpaf.predictor:batch 181: no-file-name
# INFO:__main__:frame 182, loop time = 673ms (pre = 93.6ms, post = 367.5ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 12, 11, 5, 6]
# INFO:openpifpaf.predictor:batch 182: no-file-name
# INFO:__main__:frame 183, loop time = 684ms (pre = 105.4ms, post = 385.7ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 15, 11, 12, 5, 6]
# INFO:openpifpaf.predictor:batch 183: no-file-name
# INFO:__main__:frame 184, loop time = 535ms (pre = 100.8ms, post = 261.9ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 13, 11, 11, 8]
# INFO:openpifpaf.predictor:batch 184: no-file-name
# INFO:__main__:frame 185, loop time = 510ms (pre = 131.5ms, post = 230.4ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 13, 11, 11, 8]
# INFO:openpifpaf.predictor:batch 185: no-file-name
# INFO:__main__:frame 186, loop time = 481ms (pre = 90.8ms, post = 207.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 11, 10, 9, 8, 6]
# INFO:openpifpaf.predictor:batch 186: no-file-name
# INFO:__main__:frame 187, loop time = 499ms (pre = 50.4ms, post = 225.8ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 11, 10, 9, 8, 7]
# INFO:openpifpaf.predictor:batch 187: no-file-name
# INFO:__main__:frame 188, loop time = 507ms (pre = 45.2ms, post = 228.5ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 15, 10, 9, 11, 7, 7, 8]
# INFO:openpifpaf.predictor:batch 188: no-file-name
# INFO:__main__:frame 189, loop time = 502ms (pre = 85.1ms, post = 225.5ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 15, 14, 9, 9, 7, 8, 4]
# INFO:openpifpaf.predictor:batch 189: no-file-name
# INFO:__main__:frame 190, loop time = 506ms (pre = 89.2ms, post = 227.4ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [16, 13, 12, 14, 7, 6, 5]
# INFO:openpifpaf.predictor:batch 190: no-file-name
# INFO:__main__:frame 191, loop time = 528ms (pre = 61.4ms, post = 240.3ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 13, 14, 7, 6, 4]
# INFO:openpifpaf.predictor:batch 191: no-file-name
# INFO:__main__:frame 192, loop time = 488ms (pre = 47.5ms, post = 211.9ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 16, 12, 11, 8, 6, 5, 4]
# INFO:openpifpaf.predictor:batch 192: no-file-name
# INFO:__main__:frame 193, loop time = 485ms (pre = 54.4ms, post = 213.9ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 8: [17, 16, 12, 11, 8, 7, 5, 4]
# INFO:openpifpaf.predictor:batch 193: no-file-name
# INFO:__main__:frame 194, loop time = 503ms (pre = 90.1ms, post = 224.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 9, 11, 7, 9]
# INFO:openpifpaf.predictor:batch 194: no-file-name
# INFO:__main__:frame 195, loop time = 513ms (pre = 53.0ms, post = 239.9ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 14, 10, 6]
# INFO:openpifpaf.predictor:batch 195: no-file-name
# INFO:__main__:frame 196, loop time = 479ms (pre = 44.3ms, post = 202.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [16, 17, 10, 9, 8, 11]
# INFO:openpifpaf.predictor:batch 196: no-file-name
# INFO:__main__:frame 197, loop time = 486ms (pre = 70.7ms, post = 211.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 14, 10, 9, 10, 7]
# INFO:openpifpaf.predictor:batch 197: no-file-name
# INFO:__main__:frame 198, loop time = 492ms (pre = 81.8ms, post = 214.9ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 15, 10, 9, 7, 7]
# INFO:openpifpaf.predictor:batch 198: no-file-name
# INFO:__main__:frame 199, loop time = 503ms (pre = 68.9ms, post = 235.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 15, 10, 10, 7, 7]
# INFO:openpifpaf.predictor:batch 199: no-file-name
# INFO:__main__:frame 200, loop time = 517ms (pre = 54.3ms, post = 222.9ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 10, 11, 7, 7]
# INFO:openpifpaf.predictor:batch 200: no-file-name
# INFO:__main__:frame 201, loop time = 487ms (pre = 68.2ms, post = 207.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 10, 11, 7, 7]
# INFO:openpifpaf.predictor:batch 201: no-file-name
# INFO:__main__:frame 202, loop time = 475ms (pre = 85.8ms, post = 206.4ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 10, 9]
# INFO:openpifpaf.predictor:batch 202: no-file-name
# INFO:__main__:frame 203, loop time = 505ms (pre = 55.8ms, post = 234.6ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 16, 10, 9, 10, 7]
# INFO:openpifpaf.predictor:batch 203: no-file-name
# INFO:__main__:frame 204, loop time = 540ms (pre = 53.6ms, post = 252.9ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 10, 10, 11, 7]
# INFO:openpifpaf.predictor:batch 204: no-file-name
# INFO:__main__:frame 205, loop time = 648ms (pre = 75.5ms, post = 332.6ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 12, 10]
# INFO:openpifpaf.predictor:batch 205: no-file-name
# INFO:__main__:frame 206, loop time = 725ms (pre = 93.2ms, post = 333.2ms), FPS = 1.4
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 12, 10]
# INFO:openpifpaf.predictor:batch 206: no-file-name
# INFO:__main__:frame 207, loop time = 656ms (pre = 112.7ms, post = 341.6ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 15, 13, 10, 6]
# INFO:openpifpaf.predictor:batch 207: no-file-name
# INFO:__main__:frame 208, loop time = 695ms (pre = 56.7ms, post = 360.2ms), FPS = 1.4
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 10, 11]
# INFO:openpifpaf.predictor:batch 208: no-file-name
# INFO:__main__:frame 209, loop time = 635ms (pre = 122.2ms, post = 338.4ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 13, 10, 12, 7]
# INFO:openpifpaf.predictor:batch 209: no-file-name
# INFO:__main__:frame 210, loop time = 646ms (pre = 185.6ms, post = 334.8ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 13, 11, 10, 10, 9]
# INFO:openpifpaf.predictor:batch 210: no-file-name
# INFO:__main__:frame 211, loop time = 547ms (pre = 130.0ms, post = 252.6ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 13, 11, 10, 10, 9]
# INFO:openpifpaf.predictor:batch 211: no-file-name
# INFO:__main__:frame 212, loop time = 501ms (pre = 102.1ms, post = 219.8ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 7: [17, 17, 13, 10, 10, 8, 5]
# INFO:openpifpaf.predictor:batch 212: no-file-name
# INFO:__main__:frame 213, loop time = 483ms (pre = 74.7ms, post = 213.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 15, 13, 11, 10, 9]
# INFO:openpifpaf.predictor:batch 213: no-file-name
# INFO:__main__:frame 214, loop time = 480ms (pre = 99.3ms, post = 205.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 15, 11, 12, 10, 9]
# INFO:openpifpaf.predictor:batch 214: no-file-name
# INFO:__main__:frame 215, loop time = 503ms (pre = 48.4ms, post = 229.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 15, 11, 12, 10, 9]
# INFO:openpifpaf.predictor:batch 215: no-file-name
# INFO:__main__:frame 216, loop time = 486ms (pre = 45.9ms, post = 208.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 12, 12, 10, 9]
# INFO:openpifpaf.predictor:batch 216: no-file-name
# INFO:__main__:frame 217, loop time = 485ms (pre = 67.2ms, post = 213.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 6: [17, 17, 12, 11, 10, 9]
# INFO:openpifpaf.predictor:batch 217: no-file-name
# INFO:__main__:frame 218, loop time = 486ms (pre = 85.7ms, post = 206.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 15, 10]
# INFO:openpifpaf.predictor:batch 218: no-file-name
# INFO:__main__:frame 219, loop time = 495ms (pre = 54.9ms, post = 208.2ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 13, 10]
# INFO:openpifpaf.predictor:batch 219: no-file-name
# INFO:__main__:frame 220, loop time = 486ms (pre = 49.7ms, post = 202.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 13, 10]
# INFO:openpifpaf.predictor:batch 220: no-file-name
# INFO:__main__:frame 221, loop time = 468ms (pre = 63.9ms, post = 196.5ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 13, 10]
# INFO:openpifpaf.predictor:batch 221: no-file-name
# INFO:__main__:frame 222, loop time = 475ms (pre = 79.6ms, post = 198.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 13, 10]
# INFO:openpifpaf.predictor:batch 222: no-file-name
# INFO:__main__:frame 223, loop time = 505ms (pre = 62.6ms, post = 214.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 14, 10]
# INFO:openpifpaf.predictor:batch 223: no-file-name
# INFO:__main__:frame 224, loop time = 491ms (pre = 48.6ms, post = 198.2ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 14, 15, 10]
# INFO:openpifpaf.predictor:batch 224: no-file-name
# INFO:__main__:frame 225, loop time = 495ms (pre = 77.2ms, post = 211.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 13, 15, 10]
# INFO:openpifpaf.predictor:batch 225: no-file-name
# INFO:__main__:frame 226, loop time = 481ms (pre = 81.9ms, post = 202.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 13, 14, 10]
# INFO:openpifpaf.predictor:batch 226: no-file-name
# INFO:__main__:frame 227, loop time = 491ms (pre = 59.6ms, post = 206.6ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 13, 14, 10]
# INFO:openpifpaf.predictor:batch 227: no-file-name
# INFO:__main__:frame 228, loop time = 478ms (pre = 52.5ms, post = 199.5ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 13, 14, 10]
# INFO:openpifpaf.predictor:batch 228: no-file-name
# INFO:__main__:frame 229, loop time = 487ms (pre = 82.5ms, post = 209.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 11, 10]
# INFO:openpifpaf.predictor:batch 229: no-file-name
# INFO:__main__:frame 230, loop time = 476ms (pre = 88.4ms, post = 193.5ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 11, 10]
# INFO:openpifpaf.predictor:batch 230: no-file-name
# INFO:__main__:frame 231, loop time = 512ms (pre = 54.5ms, post = 215.8ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 12, 10]
# INFO:openpifpaf.predictor:batch 231: no-file-name
# INFO:__main__:frame 232, loop time = 637ms (pre = 41.0ms, post = 327.2ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 11, 10]
# INFO:openpifpaf.predictor:batch 232: no-file-name
# INFO:__main__:frame 233, loop time = 655ms (pre = 78.1ms, post = 353.2ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 12, 10]
# INFO:openpifpaf.predictor:batch 233: no-file-name
# INFO:__main__:frame 234, loop time = 621ms (pre = 160.1ms, post = 319.4ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 12, 10]
# INFO:openpifpaf.predictor:batch 234: no-file-name
# INFO:__main__:frame 235, loop time = 644ms (pre = 99.8ms, post = 337.8ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 16, 12, 10]
# INFO:openpifpaf.predictor:batch 235: no-file-name
# INFO:__main__:frame 236, loop time = 656ms (pre = 80.8ms, post = 324.4ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 13, 10]
# INFO:openpifpaf.predictor:batch 236: no-file-name
# INFO:__main__:frame 237, loop time = 650ms (pre = 126.1ms, post = 328.9ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 17, 13, 10]
# INFO:openpifpaf.predictor:batch 237: no-file-name
# INFO:__main__:frame 238, loop time = 618ms (pre = 193.6ms, post = 335.1ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 15, 13, 10]
# INFO:openpifpaf.predictor:batch 238: no-file-name
# INFO:__main__:frame 239, loop time = 473ms (pre = 106.8ms, post = 195.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 17, 13, 14, 10]
# INFO:openpifpaf.predictor:batch 239: no-file-name
# INFO:__main__:frame 240, loop time = 500ms (pre = 90.0ms, post = 213.1ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 15, 11, 9, 9]
# INFO:openpifpaf.predictor:batch 240: no-file-name
# INFO:__main__:frame 241, loop time = 477ms (pre = 77.1ms, post = 194.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 15, 11, 9, 9]
# INFO:openpifpaf.predictor:batch 241: no-file-name
# INFO:__main__:frame 242, loop time = 505ms (pre = 76.2ms, post = 213.8ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 13, 12, 7, 6]
# INFO:openpifpaf.predictor:batch 242: no-file-name
# INFO:__main__:frame 243, loop time = 485ms (pre = 46.9ms, post = 206.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 12, 10, 6, 4]
# INFO:openpifpaf.predictor:batch 243: no-file-name
# INFO:__main__:frame 244, loop time = 488ms (pre = 42.1ms, post = 208.3ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 12, 10, 6, 4]
# INFO:openpifpaf.predictor:batch 244: no-file-name
# INFO:__main__:frame 245, loop time = 488ms (pre = 70.8ms, post = 203.7ms), FPS = 2.0
# INFO:openpifpaf.decoder.cifcaf:annotations 5: [17, 11, 8, 7, 5]
# INFO:openpifpaf.predictor:batch 245: no-file-name
# INFO:__main__:frame 246, loop time = 556ms (pre = 99.6ms, post = 285.6ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 7, 7]
# INFO:openpifpaf.predictor:batch 246: no-file-name
# INFO:__main__:frame 247, loop time = 462ms (pre = 55.8ms, post = 190.0ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 10, 7, 4]
# INFO:openpifpaf.predictor:batch 247: no-file-name
# INFO:__main__:frame 248, loop time = 461ms (pre = 44.8ms, post = 189.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 10, 7, 4]
# INFO:openpifpaf.predictor:batch 248: no-file-name
# INFO:__main__:frame 249, loop time = 462ms (pre = 70.6ms, post = 188.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 11, 6]
# INFO:openpifpaf.predictor:batch 249: no-file-name
# INFO:__main__:frame 250, loop time = 456ms (pre = 96.1ms, post = 185.1ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 9, 7, 4]
# INFO:openpifpaf.predictor:batch 250: no-file-name
# INFO:__main__:frame 251, loop time = 459ms (pre = 53.7ms, post = 185.2ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 11, 6]
# INFO:openpifpaf.predictor:batch 251: no-file-name
# INFO:__main__:frame 252, loop time = 460ms (pre = 51.0ms, post = 188.3ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 13, 7]
# INFO:openpifpaf.predictor:batch 252: no-file-name
# INFO:__main__:frame 253, loop time = 474ms (pre = 71.0ms, post = 207.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 12, 6, 3]
# INFO:openpifpaf.predictor:batch 253: no-file-name
# INFO:__main__:frame 254, loop time = 470ms (pre = 84.8ms, post = 193.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 12, 6, 3]
# INFO:openpifpaf.predictor:batch 254: no-file-name
# INFO:__main__:frame 255, loop time = 464ms (pre = 64.7ms, post = 190.6ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 10, 6, 4]
# INFO:openpifpaf.predictor:batch 255: no-file-name
# INFO:__main__:frame 256, loop time = 461ms (pre = 52.9ms, post = 187.0ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 9, 5, 4]
# INFO:openpifpaf.predictor:batch 256: no-file-name
# INFO:__main__:frame 257, loop time = 470ms (pre = 79.8ms, post = 192.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 9, 5]
# INFO:openpifpaf.predictor:batch 257: no-file-name
# INFO:__main__:frame 258, loop time = 460ms (pre = 84.3ms, post = 186.5ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 9, 5]
# INFO:openpifpaf.predictor:batch 258: no-file-name
# INFO:__main__:frame 259, loop time = 469ms (pre = 63.7ms, post = 188.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 8, 5, 4]
# INFO:openpifpaf.predictor:batch 259: no-file-name
# INFO:__main__:frame 260, loop time = 627ms (pre = 50.1ms, post = 316.5ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 9, 5, 4]
# INFO:openpifpaf.predictor:batch 260: no-file-name
# INFO:__main__:frame 261, loop time = 640ms (pre = 74.7ms, post = 335.6ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 10, 4]
# INFO:openpifpaf.predictor:batch 261: no-file-name
# INFO:__main__:frame 262, loop time = 600ms (pre = 158.2ms, post = 297.6ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 2: [17, 10]
# INFO:openpifpaf.predictor:batch 262: no-file-name
# INFO:__main__:frame 263, loop time = 598ms (pre = 121.4ms, post = 302.6ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 12, 3]
# INFO:openpifpaf.predictor:batch 263: no-file-name
# INFO:__main__:frame 264, loop time = 625ms (pre = 84.0ms, post = 311.4ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 11, 3]
# INFO:openpifpaf.predictor:batch 264: no-file-name
# INFO:__main__:frame 265, loop time = 617ms (pre = 134.2ms, post = 320.8ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 11, 4]
# INFO:openpifpaf.predictor:batch 265: no-file-name
# INFO:__main__:frame 266, loop time = 675ms (pre = 166.1ms, post = 355.3ms), FPS = 1.5
# INFO:openpifpaf.decoder.cifcaf:annotations 4: [17, 11, 3, 3]
# INFO:openpifpaf.predictor:batch 266: no-file-name
# INFO:__main__:frame 267, loop time = 541ms (pre = 107.6ms, post = 264.1ms), FPS = 1.8
# INFO:openpifpaf.decoder.cifcaf:annotations 2: [15, 12]
# INFO:openpifpaf.predictor:batch 267: no-file-name
# INFO:__main__:frame 268, loop time = 454ms (pre = 107.1ms, post = 179.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [15, 11, 6]
# INFO:openpifpaf.predictor:batch 268: no-file-name
# INFO:__main__:frame 269, loop time = 448ms (pre = 70.2ms, post = 169.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [15, 11, 6]
# INFO:openpifpaf.predictor:batch 269: no-file-name
# INFO:__main__:frame 270, loop time = 451ms (pre = 129.4ms, post = 174.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 13, 4]
# INFO:openpifpaf.predictor:batch 270: no-file-name
# INFO:__main__:frame 271, loop time = 484ms (pre = 58.2ms, post = 195.8ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 14, 4]
# INFO:openpifpaf.predictor:batch 271: no-file-name
# INFO:__main__:frame 272, loop time = 457ms (pre = 47.3ms, post = 187.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 16, 4]
# INFO:openpifpaf.predictor:batch 272: no-file-name
# INFO:__main__:frame 273, loop time = 470ms (pre = 73.8ms, post = 191.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 2: [17, 17]
# INFO:openpifpaf.predictor:batch 273: no-file-name
# INFO:__main__:frame 274, loop time = 447ms (pre = 80.8ms, post = 169.5ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 2: [17, 17]
# INFO:openpifpaf.predictor:batch 274: no-file-name
# INFO:__main__:frame 275, loop time = 480ms (pre = 47.5ms, post = 204.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 13, 4]
# INFO:openpifpaf.predictor:batch 275: no-file-name
# INFO:__main__:frame 276, loop time = 446ms (pre = 44.4ms, post = 175.3ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 2: [17, 14]
# INFO:openpifpaf.predictor:batch 276: no-file-name
# INFO:__main__:frame 277, loop time = 439ms (pre = 57.1ms, post = 169.8ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 2: [17, 14]
# INFO:openpifpaf.predictor:batch 277: no-file-name
# INFO:__main__:frame 278, loop time = 442ms (pre = 84.0ms, post = 168.5ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 15, 5]
# INFO:openpifpaf.predictor:batch 278: no-file-name
# INFO:__main__:frame 279, loop time = 451ms (pre = 67.2ms, post = 179.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 16, 5]
# INFO:openpifpaf.predictor:batch 279: no-file-name
# INFO:__main__:frame 280, loop time = 466ms (pre = 40.5ms, post = 185.1ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 16, 4]
# INFO:openpifpaf.predictor:batch 280: no-file-name
# INFO:__main__:frame 281, loop time = 443ms (pre = 66.7ms, post = 175.3ms), FPS = 2.3
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 16, 4]
# INFO:openpifpaf.predictor:batch 281: no-file-name
# INFO:__main__:frame 282, loop time = 464ms (pre = 80.3ms, post = 184.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 13, 4]
# INFO:openpifpaf.predictor:batch 282: no-file-name
# INFO:__main__:frame 283, loop time = 471ms (pre = 57.3ms, post = 200.4ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 14, 4]
# INFO:openpifpaf.predictor:batch 283: no-file-name
# INFO:__main__:frame 284, loop time = 465ms (pre = 48.5ms, post = 193.4ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 14, 4]
# INFO:openpifpaf.predictor:batch 284: no-file-name
# INFO:__main__:frame 285, loop time = 457ms (pre = 79.2ms, post = 183.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 13, 4]
# INFO:openpifpaf.predictor:batch 285: no-file-name
# INFO:__main__:frame 286, loop time = 450ms (pre = 85.9ms, post = 181.9ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 17, 5]
# INFO:openpifpaf.predictor:batch 286: no-file-name
# INFO:__main__:frame 287, loop time = 459ms (pre = 50.0ms, post = 182.0ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 16, 5]
# INFO:openpifpaf.predictor:batch 287: no-file-name
# INFO:__main__:frame 288, loop time = 449ms (pre = 41.5ms, post = 175.8ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 16, 5]
# INFO:openpifpaf.predictor:batch 288: no-file-name
# INFO:__main__:frame 289, loop time = 600ms (pre = 57.6ms, post = 298.5ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 16, 4]
# INFO:openpifpaf.predictor:batch 289: no-file-name
# INFO:__main__:frame 290, loop time = 606ms (pre = 93.2ms, post = 302.7ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 15, 4]
# INFO:openpifpaf.predictor:batch 290: no-file-name
# INFO:__main__:frame 291, loop time = 614ms (pre = 99.3ms, post = 299.8ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 15, 4]
# INFO:openpifpaf.predictor:batch 291: no-file-name
# INFO:__main__:frame 292, loop time = 599ms (pre = 94.4ms, post = 298.8ms), FPS = 1.7
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 11, 7]
# INFO:openpifpaf.predictor:batch 292: no-file-name
# INFO:__main__:frame 293, loop time = 630ms (pre = 67.0ms, post = 346.7ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 11, 7]
# INFO:openpifpaf.predictor:batch 293: no-file-name
# INFO:__main__:frame 294, loop time = 609ms (pre = 158.9ms, post = 318.5ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 12, 6]
# INFO:openpifpaf.predictor:batch 294: no-file-name
# INFO:__main__:frame 295, loop time = 616ms (pre = 118.3ms, post = 312.5ms), FPS = 1.6
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 12, 6]
# INFO:openpifpaf.predictor:batch 295: no-file-name
# INFO:__main__:frame 296, loop time = 537ms (pre = 80.2ms, post = 256.3ms), FPS = 1.9
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 10, 6]
# INFO:openpifpaf.predictor:batch 296: no-file-name
# INFO:__main__:frame 297, loop time = 452ms (pre = 143.0ms, post = 183.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 9, 4]
# INFO:openpifpaf.predictor:batch 297: no-file-name
# INFO:__main__:frame 298, loop time = 467ms (pre = 84.9ms, post = 184.6ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 9, 6]
# INFO:openpifpaf.predictor:batch 298: no-file-name
# INFO:__main__:frame 299, loop time = 466ms (pre = 66.2ms, post = 183.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 7, 7]
# INFO:openpifpaf.predictor:batch 299: no-file-name
# INFO:__main__:frame 300, loop time = 448ms (pre = 64.8ms, post = 180.4ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 7, 7]
# INFO:openpifpaf.predictor:batch 300: no-file-name
# INFO:__main__:frame 301, loop time = 457ms (pre = 60.5ms, post = 183.7ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 7, 7]
# INFO:openpifpaf.predictor:batch 301: no-file-name
# INFO:__main__:frame 302, loop time = 483ms (pre = 78.5ms, post = 194.0ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 7, 7]
# INFO:openpifpaf.predictor:batch 302: no-file-name
# INFO:__main__:frame 303, loop time = 476ms (pre = 51.9ms, post = 202.3ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 11, 9]
# INFO:openpifpaf.predictor:batch 303: no-file-name
# INFO:__main__:frame 304, loop time = 457ms (pre = 42.6ms, post = 188.1ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 12, 6]
# INFO:openpifpaf.predictor:batch 304: no-file-name
# INFO:__main__:frame 305, loop time = 465ms (pre = 58.4ms, post = 196.7ms), FPS = 2.1
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 12, 8]
# INFO:openpifpaf.predictor:batch 305: no-file-name
# INFO:__main__:frame 306, loop time = 467ms (pre = 99.5ms, post = 185.6ms), FPS = 2.1
# INFO:openpifpaf.stream:no more images captured
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 12, 7]
# INFO:openpifpaf.predictor:batch 306: no-file-name
# INFO:__main__:frame 307, loop time = 451ms (pre = 64.4ms, post = 181.3ms), FPS = 2.2
# INFO:openpifpaf.decoder.cifcaf:annotations 3: [17, 10, 5]
# INFO:openpifpaf.predictor:batch 307: no-file-name
# INFO:__main__:frame 308, loop time = 531ms (pre = 37.1ms, post = 264.1ms), FPS = 1.9

# %%
# /usr/local/lib/python3.10/dist-packages/openpifpaf/video.py
